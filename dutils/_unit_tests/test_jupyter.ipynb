# %%
from dutils import jupyter_ipython as jupyter

# %%
# Tests should pass
jupyter.in_jupyter()
jupyter.assert_in_jupyter()
jupyter.play_audio("./test_audio.wav")
jupyter.show_image("./test_image.png", 0.5)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <PIL.Image.Image image mode=RGB size=161x145 at 0x2849112A430>

# %%
# Should fail
jupyter.adjust_screen_width(49)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b2df1cf75205> in <module>
#       1 # Should fail
# ----> 2 jupyter.adjust_screen_width(49)
#
# ~\Desktop\Onedrive\Programming\Python\Modules\dutils\jupyter_ipython.py in adjust_screen_width(percentage)
#      44     assert_in_jupyter()
#      45     if not (50<=percentage<=100):
# ---> 46         raise ValueError(f"Expected 50 <= `percentage` <= 100, but received `{percentage}`")
#      47
#      48     # Adjust width
#
# ValueError: Expected 50 <= `percentage` <= 100, but received `49`

# %%
jupyter.adjust_screen_width(101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-678d3329cb4c> in <module>
# ----> 1 jupyter.adjust_screen_width(101)
#
# ~\Desktop\Onedrive\Programming\Python\Modules\dutils\jupyter_ipython.py in adjust_screen_width(percentage)
#      44     assert_in_jupyter()
#      45     if not (50<=percentage<=100):
# ---> 46         raise ValueError(f"Expected 50 <= `percentage` <= 100, but received `{percentage}`")
#      47
#      48     # Adjust width
#
# ValueError: Expected 50 <= `percentage` <= 100, but received `101`
